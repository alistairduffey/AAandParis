# %%
import os

# %%
os.listdir('/badc/')
# Out:
# ['.testing',
#  '.testing2',
#  'ARCHIVE_INFO',
#  'CDs',
#  'a-cure',
#  'abacus',
#  'accacia',
#  'accmip',
#  'acid-deposition',
#  'acid-pruf',
#  'acites',
#  'acruise',
#  'acse',
#  'acsis',
#  'acsoe',
#  'active',
#  'adriex',
#  'amazonica',
#  'amma',
#  'amps_antarctic',
#  'aphh',
#  'apposite',
#  'appraise',
#  'ar6_sr15',
#  'ar6_wg1',
#  'armagh',
#  'asalasca',
#  'autex-wintex',
#  'bas',
#  'bas-aircraft',
#  'bodeker-scientific-ozone',
#  'bolton',
#  'bortas',
#  'buniaac',
#  'caesar',
#  'cap',
#  'capeverde',
#  'cascade',
#  'cast',
#  'ccmi',
#  'ccmval',
#  'ceh-pan',
#  'ch4-n2o-hotspots',
#  'chablis',
#  'chilbolton',
#  'chirps',
#  'cira',
#  'claesl3',
#  'claus',
#  'clearflo',
#  'cloudmap',
#  'cmip3_drs',
#  'cmip5',
#  'cmip6',
#  'cmorph',
#  'coapec',
#  'cobra',
#  'constrain',
#  'cops',
#  'cordex',
#  'corral',
#  'covex',
#  'cpdn',
#  'cru',
#  'cryostat',
#  'csip',
#  'cwave',
#  'cwvc',
#  'dabex',
#  'deposited2017',
# ...
